# %%
import pandas as pd
import os

print(os.getcwd())
# Out:
# /mnt/c/Users/Alvin/Desktop/ML Test Scripts/mec-capstone/src/visualization

# %%
fpath = "./Test Cases.xlsx"
pd.read_excel(fpath)
# Out:
#     Number                                              Start  \
# 0        1                                    Classic Risotto
# 1        2  Easy Brown Rice Risotto with Mushrooms and Fre...
# 2        3                                     Chipotle Chili
# 3        4       Butternut Squash Chipotle Chili with Avocado
# 4        5                                    Beef Stroganoff
# 5        6                     Portobello Mushroom Stroganoff
# 6        7                                Ragu with Bolognese
# 7        8                                   Lentil Bolognese
# 8        9                                        Sloppy Joes
# 9       10                             Vegetarian Sloppy Joes
# 10      11                                       Beef Pot Pie
# 11      12                               Mushroom Pulled Pork
# 12      13                               Pulled Pork Sandwich
# 13      14                          Buttermilk Fried Mushroom
# ...

# %%
import pandas as pd
import os

print(os.getcwd())
# Out:
# /mnt/c/Users/Alvin/Desktop/ML Test Scripts/mec-capstone/src/visualization

# %%
fpath = "./Test Cases.xlsx"
pd.read_excel(fpath)
# Out:
#                                            start_name  \
# 0                                     Classic Risotto
# 1   Easy Brown Rice Risotto with Mushrooms and Fre...
# 2                                      Chipotle Chili
# 3        Butternut Squash Chipotle Chili with Avocado
# 4                                     Beef Stroganoff
# 5                      Portobello Mushroom Stroganoff
# 6                                 Ragu with Bolognese
# 7                                    Lentil Bolognese
# 8                                         Sloppy Joes
# 9                              Vegetarian Sloppy Joes
# 10                                       Beef Pot Pie
# 11                               Mushroom Pulled Pork
# 12                               Pulled Pork Sandwich
# 13                          Buttermilk Fried Mushroom
# 14                           Buttermilk Fried Chicken
# 15                                    Beef Stroganoff
# ...
